# %%
import os, sys, warnings
import numpy as np, sequentia as seq, matplotlib.pyplot as plt
import sequentia.preprocessing
from sequentia.classifiers import HMM, HMMClassifier, DTWKNN
from tqdm.auto import tqdm

# Import utility functions and classes
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils import *
from lstm import LSTMClassifier

# Filter warnings
warnings.filterwarnings('ignore')

# ggplot style
plt.style.use('ggplot')

# Set seed for reproducible randomness
seed = 0
np.random.seed(seed)
rng = np.random.RandomState(seed=seed)

# %%
gestures_map = {
    'nd': 'nod',
    'mnd': 'multiple nods',
    'fu': 'face-up',
    'fd': 'face-down',
    'sh': 'shake',
    't': 'turn',
    'ti': 'tilt'
}

gestures = list(gestures_map.keys())

# %%
fields = ['Rx', 'Ry', 'Rz', 'Tx', 'Ty', 'Tz']

# %%
# Containers to store classifiers and results
clfs, results = {}, {'hmm': {}, 'knn': {}, 'lstm': {}}

# %%
# Load the MoCap dataset
loader = MoCapLoader(normalized=False)
X, y = loader.load(fields)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Converting dataframes to Numpy arrays', layout=Layout(fle…

# %% [markdown]
# ## Dataset splits
#
# Create a stratified 65-20-15 training, validation and test set split.

# %%
# Create a stratified training, validation and test set split (65-20-15)
X_train, X_val, X_test, y_train, y_val, y_test = data_split(X, y, random_state=rng, stratify=True)
# Out:
# Training set size: 841
# Validation set size: 258
# Test set size: 196

# %%
# MoCap dataset class counts (training set)
show_class_counts(y_train, gestures, title=None)

# %%
# Histogram of MoCap dataset gesture durations (training set)
show_durations(X_train, bins=75, title=None)

# %% [markdown]
# ## Preprocessing

# %%
# Create a preprocessing pipeline
def pre(XX):
    XX = seq.preprocessing.filtrate(XX, n=10, method='median')
    XX = smart_downsample(XX, m=50, method='decimate')
    XX = seq.preprocessing.center(XX)
    return XX

# %%
# Function for visualizing gesture signals
def plot_gesture(gesture, label, figsize=(10, 5), same_scale=True, title=None):
    title = "Head rotation and translation vectors for a '{}' gesture".format(gestures_map[label]) if title is None else title
    labels = ['$R_x$ (Roll)', '$R_y$ (Yaw)', '$R_z$ (Pitch)', '$T_x$', '$T_y$', '$T_z$']
    colors = ['blue', 'red', 'green'] * 2
    fig, axs = plt.subplots(3, 2, sharex=True, figsize=figsize)
    
    for i in range(3):
        ax1, ax2 = axs[i, 0], axs[i, 1]
        ax1.plot(gesture[:, i], label=labels[i], color=colors[i])
        ax2.plot(gesture[:, i+3], label=labels[i+3], color=colors[i+3])
        ax1.legend(loc='lower right')
        ax2.legend(loc='lower right')
        if same_scale:
            pad = 0.1
            ax1.set_ylim(gesture.min()-pad, gesture.max()+pad)
            ax2.set_ylim(gesture.min()-pad, gesture.max()+pad)
            
    fig.tight_layout()
    fig.subplots_adjust(top=0.92)
    fig.suptitle(title)
    plt.show()

# %%
# Pick an example signal for visualization
x_sample, y_sample = X_train[0], y_train[0]
plot_gesture(x_sample, y_sample, title="Head rotation vectors for a '{}' gesture (before preprocessing)".format(y_sample))
plot_gesture(pre(x_sample), y_sample, title="Head rotation vectors for a '{}' gesture (after preprocessing)".format(y_sample))

# %%
# Transform training data and plot histogram of MoCap dataset gesture durations (training set)
Xp_train = pre(X_train)
show_durations(Xp_train, bins=75, title=None)

# %%
# Apply the preprocessing pipeline to the other dataset splits
Xp_val, Xp_test = pre(X_val), pre(X_test)

# %% [markdown]
# ## DTWKNN classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
# Create and fit a DTWKNN classifier using the single nearest neighbor and a radius of 1
# NOTE: The radius parameter is a parameter that constrains the FastDTW algorithm.
clfs['knn'] = DTWKNN(k=1, radius=1)
clfs['knn'].fit(Xp_train, y_train)
# Out:
# CPU times: user 3.86 ms, sys: 1.95 ms, total: 5.81 ms
# Wall time: 4.51 ms

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['knn']['validation'] = clfs['knn'].evaluate(Xp_val, y_val, labels=gestures, n_jobs=-1)
show_results(*results['knn']['validation'], dataset='validation', labels=gestures)
# Out:
# Accuracy: 41.09%
# CPU times: user 716 ms, sys: 324 ms, total: 1.04 s
# Wall time: 1h 1min 50s

# %% [markdown]
# ## Hidden Markov Model classifier
#
# One gesture model $\lambda_i=(A_i,B_i,\pi_i)$ is initialized and trained for each of the gestures: `nd`, `mnd`, `sh`, `fd`, `t`, `ti`, `fu`.

# %% [markdown]
# ### Fitting the model

# %%
# %%time

# Create HMMs to represent each class
#
# NumPy sometimes raises some errors as a result of instability during the Cholesky decomposition.
# According to issue #414 on Pomegranate's GitHub repository, this may be caused by:
# - Too many states in the HMMs
# - Too many dimensions in the input data, which leads to a large covariance matrix
# - Too few training examples
hmms = []
for g in tqdm(gestures, desc='Training HMMs'):
    hmm = HMM(label=g, n_states=7, random_state=rng)
    hmm.set_random_initial()
    hmm.set_random_transitions()
    hmm.fit([Xp_train[i] for i, label in enumerate(y_train) if label == g])
    hmms.append(hmm)
    
# Fit a HMM classifier with the HMMs
clfs['hmm'] = HMMClassifier()
clfs['hmm'].fit(hmms)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Training HMMs', max=7.0, style=ProgressStyle(description_…
# CPU times: user 30.4 s, sys: 748 ms, total: 31.1 s
# Wall time: 39.9 s

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['hmm']['validation'] = clfs['hmm'].evaluate(Xp_val, y_val)
show_results(*results['hmm']['validation'], dataset='validation', labels=gestures)
# Out:
# Accuracy: 37.60%
# CPU times: user 1.03 s, sys: 51.1 ms, total: 1.08 s
# Wall time: 1.42 s

# %%
with np.printoptions(precision=3, suppress=True):
    display(hmms[0].initial, hmms[0].transitions)
# Out:
# array([0.261, 0.205, 0.123, 0.199, 0.077, 0.036, 0.1  ])
# array([[0.97 , 0.008, 0.015, 0.006, 0.   , 0.001, 0.   ],
#        [0.   , 0.99 , 0.003, 0.001, 0.   , 0.004, 0.002],
#        [0.   , 0.   , 0.984, 0.005, 0.   , 0.006, 0.005],
#        [0.   , 0.   , 0.   , 0.993, 0.002, 0.002, 0.003],
#        [0.   , 0.   , 0.   , 0.   , 0.998, 0.002, 0.   ],
#        [0.   , 0.   , 0.   , 0.   , 0.   , 0.999, 0.001],
#        [0.   , 0.   , 0.   , 0.   , 0.   , 0.   , 1.   ]])

# %% [markdown]
# ## LSTM classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
from tensorflow.keras.optimizers import Adam
clfs['lstm'] = LSTMClassifier(epochs=125, batch_size=128, optimizer=Adam(learning_rate=0.002), classes=gestures)
hist = clfs['lstm'].fit(Xp_train, y_train, validation_data=(Xp_val, y_val), return_history=True)
# Out:
# Train on 841 samples, validate on 258 samples
# Epoch 1/125
# 841/841 [==============================] - 4s 4ms/sample - loss: 1.9349 - accuracy: 0.2081 - val_loss: 1.9041 - val_accuracy: 0.2171
# Epoch 2/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8762 - accuracy: 0.2449 - val_loss: 1.8610 - val_accuracy: 0.2287
# Epoch 3/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8626 - accuracy: 0.2307 - val_loss: 1.8601 - val_accuracy: 0.2287
# Epoch 4/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8592 - accuracy: 0.2426 - val_loss: 1.8560 - val_accuracy: 0.2248
# Epoch 5/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8606 - accuracy: 0.2342 - val_loss: 1.8547 - val_accuracy: 0.2326
# Epoch 6/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8547 - accuracy: 0.2331 - val_loss: 1.8496 - val_accuracy: 0.2287
# Epoch 7/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8768 - accuracy: 0.2663 - val_loss: 1.8591 - val_accuracy: 0.2364
# Epoch 8/125
# 841/841 [==============================] - 3s 4ms/sample - loss: 1.8642 - accuracy: 0.2224 - val_loss: 1.8579 - val_accuracy: 0.2326
# Epoch 9/125
# 841/841 [==============================] - 3s 3ms/sample - loss: 1.8587 - accuracy: 0.2283 - val_loss: 1.8571 - val_accuracy: 0.2287
# Epoch 10/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8549 - accuracy: 0.2354 - val_loss: 1.8579 - val_accuracy: 0.2326
# Epoch 11/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8584 - accuracy: 0.2295 - val_loss: 1.8565 - val_accuracy: 0.2248
# Epoch 12/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8566 - accuracy: 0.2224 - val_loss: 1.8557 - val_accuracy: 0.2171
# Epoch 13/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8490 - accuracy: 0.2200 - val_loss: 1.8529 - val_accuracy: 0.2209
# Epoch 14/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8506 - accuracy: 0.2366 - val_loss: 1.8465 - val_accuracy: 0.2248
# Epoch 15/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8430 - accuracy: 0.2366 - val_loss: 1.8388 - val_accuracy: 0.2829
# Epoch 16/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8344 - accuracy: 0.2414 - val_loss: 1.8356 - val_accuracy: 0.2752
# Epoch 17/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8368 - accuracy: 0.2354 - val_loss: 1.8382 - val_accuracy: 0.2248
# Epoch 18/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8190 - accuracy: 0.2342 - val_loss: 1.8384 - val_accuracy: 0.2481
# Epoch 19/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8069 - accuracy: 0.2604 - val_loss: 1.8596 - val_accuracy: 0.2597
# Epoch 20/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8361 - accuracy: 0.2652 - val_loss: 1.8396 - val_accuracy: 0.2519
# Epoch 21/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8332 - accuracy: 0.2759 - val_loss: 1.8511 - val_accuracy: 0.2597
# Epoch 22/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8249 - accuracy: 0.2652 - val_loss: 1.8402 - val_accuracy: 0.2442
# Epoch 23/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8133 - accuracy: 0.2675 - val_loss: 1.8463 - val_accuracy: 0.2442
# Epoch 24/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8282 - accuracy: 0.2604 - val_loss: 1.8515 - val_accuracy: 0.2326
# Epoch 25/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.8422 - accuracy: 0.2426 - val_loss: 1.8476 - val_accuracy: 0.2364
# Epoch 26/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8379 - accuracy: 0.2509 - val_loss: 1.8473 - val_accuracy: 0.1938
# Epoch 27/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8363 - accuracy: 0.2354 - val_loss: 1.8434 - val_accuracy: 0.2093
# Epoch 28/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8303 - accuracy: 0.2307 - val_loss: 1.8384 - val_accuracy: 0.2054
# Epoch 29/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8256 - accuracy: 0.2259 - val_loss: 1.8364 - val_accuracy: 0.2364
# Epoch 30/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8220 - accuracy: 0.2711 - val_loss: 1.8356 - val_accuracy: 0.2287
# Epoch 31/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8191 - accuracy: 0.2426 - val_loss: 1.8330 - val_accuracy: 0.2171
# Epoch 32/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.8171 - accuracy: 0.2461 - val_loss: 1.8330 - val_accuracy: 0.2558
# Epoch 33/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8064 - accuracy: 0.2556 - val_loss: 1.8239 - val_accuracy: 0.2287
# Epoch 34/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8093 - accuracy: 0.2580 - val_loss: 1.8339 - val_accuracy: 0.2442
# Epoch 35/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.8140 - accuracy: 0.2556 - val_loss: 1.8184 - val_accuracy: 0.2674
# Epoch 36/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.7889 - accuracy: 0.2556 - val_loss: 1.8049 - val_accuracy: 0.2713
# Epoch 37/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.7733 - accuracy: 0.2889 - val_loss: 1.8061 - val_accuracy: 0.2636
# Epoch 38/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.7657 - accuracy: 0.2640 - val_loss: 1.7970 - val_accuracy: 0.2713
# Epoch 39/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7657 - accuracy: 0.2866 - val_loss: 1.8128 - val_accuracy: 0.2829
# Epoch 40/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7633 - accuracy: 0.2794 - val_loss: 1.7892 - val_accuracy: 0.2868
# Epoch 41/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.7563 - accuracy: 0.2806 - val_loss: 1.8173 - val_accuracy: 0.2597
# Epoch 42/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.7604 - accuracy: 0.2818 - val_loss: 1.8249 - val_accuracy: 0.2636
# Epoch 43/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.7663 - accuracy: 0.2771 - val_loss: 1.8155 - val_accuracy: 0.2752
# Epoch 44/125
# 841/841 [==============================] - 3s 4ms/sample - loss: 1.7427 - accuracy: 0.2699 - val_loss: 1.8110 - val_accuracy: 0.2752
# Epoch 45/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.7515 - accuracy: 0.2913 - val_loss: 1.8130 - val_accuracy: 0.3178
# Epoch 46/125
# 841/841 [==============================] - 3s 3ms/sample - loss: 1.7453 - accuracy: 0.2866 - val_loss: 1.7906 - val_accuracy: 0.2907
# Epoch 47/125
# 841/841 [==============================] - 2s 3ms/sample - loss: 1.7360 - accuracy: 0.2866 - val_loss: 1.7631 - val_accuracy: 0.2829
# Epoch 48/125
# 841/841 [==============================] - 2s 3ms/sample - loss: 1.7193 - accuracy: 0.2973 - val_loss: 1.7594 - val_accuracy: 0.2984
# Epoch 49/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.7107 - accuracy: 0.2913 - val_loss: 1.7541 - val_accuracy: 0.2984
# Epoch 50/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7147 - accuracy: 0.3151 - val_loss: 1.7314 - val_accuracy: 0.3450
# Epoch 51/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6865 - accuracy: 0.3151 - val_loss: 1.7227 - val_accuracy: 0.2946
# Epoch 52/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7000 - accuracy: 0.3127 - val_loss: 1.7280 - val_accuracy: 0.3256
# Epoch 53/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7116 - accuracy: 0.3092 - val_loss: 1.7382 - val_accuracy: 0.3450
# Epoch 54/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.7383 - accuracy: 0.2996 - val_loss: 1.7833 - val_accuracy: 0.2752
# Epoch 55/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.7418 - accuracy: 0.2901 - val_loss: 1.7565 - val_accuracy: 0.2907
# Epoch 56/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.7205 - accuracy: 0.3187 - val_loss: 1.7383 - val_accuracy: 0.3062
# Epoch 57/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6957 - accuracy: 0.3103 - val_loss: 1.7176 - val_accuracy: 0.3062
# Epoch 58/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6734 - accuracy: 0.3246 - val_loss: 1.7400 - val_accuracy: 0.3062
# Epoch 59/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6680 - accuracy: 0.3234 - val_loss: 1.7358 - val_accuracy: 0.3178
# Epoch 60/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6981 - accuracy: 0.3008 - val_loss: 1.7143 - val_accuracy: 0.3450
# Epoch 61/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6628 - accuracy: 0.3306 - val_loss: 1.7228 - val_accuracy: 0.3023
# Epoch 62/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6650 - accuracy: 0.3317 - val_loss: 1.7068 - val_accuracy: 0.3023
# Epoch 63/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6364 - accuracy: 0.3341 - val_loss: 1.7175 - val_accuracy: 0.2907
# Epoch 64/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6434 - accuracy: 0.3329 - val_loss: 1.6890 - val_accuracy: 0.3333
# Epoch 65/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6029 - accuracy: 0.3555 - val_loss: 1.7438 - val_accuracy: 0.3140
# Epoch 66/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6666 - accuracy: 0.3377 - val_loss: 1.7336 - val_accuracy: 0.3062
# Epoch 67/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.6923 - accuracy: 0.3234 - val_loss: 1.6872 - val_accuracy: 0.3256
# Epoch 68/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6428 - accuracy: 0.3448 - val_loss: 1.6834 - val_accuracy: 0.3527
# Epoch 69/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6507 - accuracy: 0.3436 - val_loss: 1.6810 - val_accuracy: 0.3488
# Epoch 70/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6218 - accuracy: 0.3543 - val_loss: 1.6822 - val_accuracy: 0.3488
# Epoch 71/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.6472 - accuracy: 0.3484 - val_loss: 1.7395 - val_accuracy: 0.3217
# Epoch 72/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6832 - accuracy: 0.3246 - val_loss: 1.7379 - val_accuracy: 0.3372
# Epoch 73/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.6533 - accuracy: 0.3460 - val_loss: 1.7273 - val_accuracy: 0.3101
# Epoch 74/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.6271 - accuracy: 0.3603 - val_loss: 1.7137 - val_accuracy: 0.3217
# Epoch 75/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.6144 - accuracy: 0.3496 - val_loss: 1.6702 - val_accuracy: 0.3256
# Epoch 76/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5765 - accuracy: 0.3650 - val_loss: 1.6897 - val_accuracy: 0.3798
# Epoch 77/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.5789 - accuracy: 0.3662 - val_loss: 1.7665 - val_accuracy: 0.2907
# Epoch 78/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.6145 - accuracy: 0.3436 - val_loss: 1.7483 - val_accuracy: 0.3023
# Epoch 79/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.6237 - accuracy: 0.3484 - val_loss: 1.7286 - val_accuracy: 0.3372
# Epoch 80/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5854 - accuracy: 0.3698 - val_loss: 1.7401 - val_accuracy: 0.3411
# Epoch 81/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.5987 - accuracy: 0.3615 - val_loss: 1.6710 - val_accuracy: 0.3333
# Epoch 82/125
# 841/841 [==============================] - 3s 3ms/sample - loss: 1.5760 - accuracy: 0.3781 - val_loss: 1.6578 - val_accuracy: 0.3566
# Epoch 83/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5433 - accuracy: 0.3888 - val_loss: 1.7064 - val_accuracy: 0.3411
# Epoch 84/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5553 - accuracy: 0.3876 - val_loss: 1.6883 - val_accuracy: 0.3527
# Epoch 85/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5325 - accuracy: 0.3698 - val_loss: 1.7599 - val_accuracy: 0.3333
# Epoch 86/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5657 - accuracy: 0.3900 - val_loss: 1.6430 - val_accuracy: 0.3760
# Epoch 87/125
# 841/841 [==============================] - 2s 3ms/sample - loss: 1.5438 - accuracy: 0.3900 - val_loss: 1.6765 - val_accuracy: 0.3488
# Epoch 88/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5431 - accuracy: 0.4078 - val_loss: 1.6362 - val_accuracy: 0.3798
# Epoch 89/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.5002 - accuracy: 0.4102 - val_loss: 1.6691 - val_accuracy: 0.3333
# Epoch 90/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.5100 - accuracy: 0.4102 - val_loss: 1.6800 - val_accuracy: 0.3682
# Epoch 91/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.5286 - accuracy: 0.4043 - val_loss: 1.7171 - val_accuracy: 0.3256
# Epoch 92/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4955 - accuracy: 0.4126 - val_loss: 1.6272 - val_accuracy: 0.3760
# Epoch 93/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4769 - accuracy: 0.4221 - val_loss: 1.5764 - val_accuracy: 0.4225
# Epoch 94/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4972 - accuracy: 0.4185 - val_loss: 1.6385 - val_accuracy: 0.3643
# Epoch 95/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4758 - accuracy: 0.4138 - val_loss: 1.6093 - val_accuracy: 0.4225
# Epoch 96/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4422 - accuracy: 0.4376 - val_loss: 1.6655 - val_accuracy: 0.3837
# Epoch 97/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4417 - accuracy: 0.4637 - val_loss: 1.6410 - val_accuracy: 0.4070
# Epoch 98/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4220 - accuracy: 0.4554 - val_loss: 1.7179 - val_accuracy: 0.3566
# Epoch 99/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4071 - accuracy: 0.4602 - val_loss: 1.6742 - val_accuracy: 0.3992
# Epoch 100/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.5140 - accuracy: 0.3995 - val_loss: 1.5985 - val_accuracy: 0.4070
# Epoch 101/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4949 - accuracy: 0.4174 - val_loss: 1.6049 - val_accuracy: 0.4225
# Epoch 102/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4468 - accuracy: 0.4435 - val_loss: 1.6391 - val_accuracy: 0.3798
# Epoch 103/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4440 - accuracy: 0.4447 - val_loss: 1.5980 - val_accuracy: 0.4341
# Epoch 104/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4364 - accuracy: 0.4602 - val_loss: 1.6123 - val_accuracy: 0.3915
# Epoch 105/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4671 - accuracy: 0.4221 - val_loss: 1.5923 - val_accuracy: 0.4186
# Epoch 106/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4376 - accuracy: 0.4483 - val_loss: 1.6623 - val_accuracy: 0.3527
# Epoch 107/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4837 - accuracy: 0.4233 - val_loss: 1.6624 - val_accuracy: 0.3682
# Epoch 108/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.4699 - accuracy: 0.4078 - val_loss: 1.6278 - val_accuracy: 0.4109
# Epoch 109/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.3879 - accuracy: 0.4744 - val_loss: 1.6171 - val_accuracy: 0.4302
# Epoch 110/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.3782 - accuracy: 0.4661 - val_loss: 1.6153 - val_accuracy: 0.4380
# Epoch 111/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.3617 - accuracy: 0.4685 - val_loss: 1.6810 - val_accuracy: 0.3953
# Epoch 112/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.4431 - accuracy: 0.4518 - val_loss: 1.6587 - val_accuracy: 0.3798
# Epoch 113/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.4008 - accuracy: 0.4578 - val_loss: 1.6487 - val_accuracy: 0.3837
# Epoch 114/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4253 - accuracy: 0.4411 - val_loss: 1.7464 - val_accuracy: 0.3643
# Epoch 115/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.5031 - accuracy: 0.4281 - val_loss: 1.7367 - val_accuracy: 0.3643
# Epoch 116/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.5069 - accuracy: 0.3948 - val_loss: 1.6524 - val_accuracy: 0.3876
# Epoch 117/125
# 841/841 [==============================] - 2s 2ms/sample - loss: 1.4775 - accuracy: 0.4328 - val_loss: 1.6375 - val_accuracy: 0.3992
# Epoch 118/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4096 - accuracy: 0.4221 - val_loss: 1.6260 - val_accuracy: 0.4419
# Epoch 119/125
# 841/841 [==============================] - 1s 2ms/sample - loss: 1.3824 - accuracy: 0.4649 - val_loss: 1.6596 - val_accuracy: 0.4225
# Epoch 120/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.3535 - accuracy: 0.4875 - val_loss: 1.5621 - val_accuracy: 0.4109
# Epoch 121/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4036 - accuracy: 0.4471 - val_loss: 1.6548 - val_accuracy: 0.3915
# Epoch 122/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4165 - accuracy: 0.4495 - val_loss: 1.6457 - val_accuracy: 0.3992
# Epoch 123/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4375 - accuracy: 0.4566 - val_loss: 1.6276 - val_accuracy: 0.3992
# Epoch 124/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4076 - accuracy: 0.4209 - val_loss: 1.6765 - val_accuracy: 0.3566
# Epoch 125/125
# 841/841 [==============================] - 1s 1ms/sample - loss: 1.4035 - accuracy: 0.4530 - val_loss: 1.6971 - val_accuracy: 0.3915
# CPU times: user 4min 38s, sys: 1min 28s, total: 6min 7s
# Wall time: 3min 11s

# %%
# Display accuracy and loss history during training
show_accuracy_history(hist)
show_loss_history(hist)

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['lstm']['validation'] = clfs['lstm'].evaluate(Xp_val, y_val)
show_results(*results['lstm']['validation'], dataset='validation', labels=gestures)
# Out:
# Accuracy: 39.15%
# CPU times: user 1.03 s, sys: 120 ms, total: 1.15 s
# Wall time: 980 ms

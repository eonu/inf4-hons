# %%
import os, sys
import numpy as np, matplotlib.pyplot as plt

# Import utility functions and classes
from utils import *

# ggplot style
plt.style.use('ggplot')

# %%
gestures_map = {
    'nd': 'nod',
    'mnd': 'multiple nods',
    'fu': 'face-up',
    'fd': 'face-down',
    'sh': 'shake',
    't': 'turn',
    'ti': 'tilt'
}

gestures = list(gestures_map.keys())

# %%
fields = ['Rx', 'Ry', 'Rz', 'Tx', 'Ty', 'Tz']

# Load the MoCap dataset
loader = MoCapLoader(normalized=False)
_, y = loader.load(fields)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Converting dataframes to Numpy arrays', layout=Layout(fle…

# %%
show_class_counts(y, gestures, title=None, figsize=(9, 5), save='class-counts.pdf')

# %% [markdown]
# # Introduction
#
# Experimentation on the [UC2018 DualMyo Hand Gesture Dataset](https://zenodo.org/record/1320922#.Xi9l5xfgoWo).

# %%
import os, sys, requests, pickle
import numpy as np, matplotlib.pyplot as plt
from sequentia.classifiers import HMM, HMMClassifier, DTWKNN
from sequentia.preprocessing import Preprocess
from tqdm.auto import tqdm

# Silence TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# Import utility functions and classes
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils import *
from lstm import LSTMClassifier

# ggplot style
plt.style.use('ggplot')

# Set seed for reproducible randomness
seed = 0
np.random.seed(seed)
rng = np.random.RandomState(seed)

# %%
n_classes = 8
classes = [str(i) for i in range(n_classes)]
classes
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']

# %%
clfs, results = {}, {'hmm': {}, 'knn': {}, 'lstm': {}}

# %%
X, y = [], []
url = 'https://zenodo.org/record/1320922/files/dualmyo_dataset.pkl'

try:
    file = 'dualmyo_dataset.pkl'
    print('Downloading dataset from {} ...'.format(url))
    response = requests.get(url)
    with open(file, 'wb') as f:
        print('Writing {} ...'.format(file))
        f.write(response.content)
except:
    raise
else:
    print('Unpickling data into Numpy arrays ...')
    data = pickle.load(open(file, 'rb'))
    X = data[0]
    y = [str(label) for label in data[1]]
    print('Done!')
finally:
    os.remove(file)
# Out:
# Downloading dataset from https://zenodo.org/record/1320922/files/dualmyo_dataset.pkl ...
# Writing dualmyo_dataset.pkl ...
# Unpickling data into Numpy arrays ...
# Done!

# %% [markdown]
# ## Dataset splits
#
# Create a stratified 65-20-15 training, validation and test set split.

# %%
# Create a stratified training, validation and test set split (65-20-15)
X_train, X_val, X_test, y_train, y_val, y_test = data_split(X, y, random_state=rng, stratify=True)
# Out:
# Training set size: 572
# Validation set size: 176
# Test set size: 133

# %%
# DualMyo dataset class counts (training set)
show_class_counts(y_train, classes, title=None)

# %%
# Histogram of DualMyo dataset gesture durations (training set)
show_durations(X_train, bins=75, title=None)

# %% [markdown]
# ## Preprocessing

# %%
# Create a preprocessing pipeline
pre = Preprocess()
pre.filtrate(n=5, method='median')
pre.downsample(n=10, method='decimate')
pre.center()
pre.summary()
# Out:
#            Preprocessing summary:
# ===========================================
# 1. Filtering:
#    Median filter with window size (n=5)
# -------------------------------------------
# 2. Downsampling:
#    Decimation with downsample factor (n=10)
# -------------------------------------------
# 3. Centering
# ===========================================

# %%
# Pick an example signal for visualization
x = X_train[1]

plt.figure(figsize=(16, 3))
plt.title('Example signal before preprocessing')
plt.plot(x)
plt.show()

plt.figure(figsize=(16, 3))
plt.title('Example signal after preprocessing')
plt.plot(pre.transform(x))
plt.show()

# %%
# Transform training data and plot histogram of DualMyo dataset gesture durations (preprocessed) (training set)
Xp_train = pre.transform(X_train)
show_durations(Xp_train, bins=75, title=None)

# %%
# Apply the preprocessing pipeline to the other dataset splits
Xp_val, Xp_test = pre.transform(X_val), pre.transform(X_test)

# %% [markdown]
# ## DTWKNN classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
# Create and fit a DTWKNN classifier using the single nearest neighbor and a radius of 1
# NOTE: The radius parameter is a parameter that constrains the FastDTW algorithm.
clfs['knn'] = DTWKNN(k=1, radius=1)
clfs['knn'].fit(Xp_train, y_train)
# Out:
# CPU times: user 1.55 ms, sys: 1.2 ms, total: 2.74 ms
# Wall time: 2.32 ms

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['knn']['validation'] = clfs['knn'].evaluate(Xp_val, y_val, labels=classes, n_jobs=-1)
show_results(*results['knn']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 12.50%
# CPU times: user 604 ms, sys: 425 ms, total: 1.03 s
# Wall time: 1min 42s

# %% [markdown]
# ## Hidden Markov Model classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time

# Create HMMs to represent each class
#
# NumPy sometimes raises some errors as a result of instability during the Cholesky decomposition.
# According to issue #414 on Pomegranate's GitHub repository, this may be caused by:
# - Too many states in the HMMs
# - Too many dimensions in the input data, which leads to a large covariance matrix
# - Too few training examples
hmms = []
for c in tqdm(classes, desc='Training HMMs'):
    hmm = HMM(label=c, n_states=7, random_state=rng)
    hmm.set_random_initial()
    hmm.set_random_transitions()
    hmm.fit([Xp_train[i] for i, label in enumerate(y_train) if label == c])
    hmms.append(hmm)
    
# Fit a HMM classifier with the HMMs
clfs['hmm'] = HMMClassifier()
clfs['hmm'].fit(hmms)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Training HMMs', max=8.0, style=ProgressStyle(description_…
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 19-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 19-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 20-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 18-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 9-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 9-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ...
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 15-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# CPU times: user 1min 13s, sys: 1min 21s, total: 2min 34s
# Wall time: 28.1 s

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['hmm']['validation'] = clfs['hmm'].evaluate(Xp_val, y_val, labels=classes)
show_results(*results['hmm']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 99.43%
# CPU times: user 602 ms, sys: 132 ms, total: 734 ms
# Wall time: 554 ms

# %% [markdown]
# ## LSTM classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
clfs['lstm'] = LSTMClassifier(epochs=30, batch_size=64, classes=classes)
hist = clfs['lstm'].fit(Xp_train, y_train, validation_data=(Xp_val, y_val), return_history=True)
# Out:
# Train on 572 samples, validate on 176 samples
# Epoch 1/30
# 572/572 [==============================] - 3s 6ms/sample - loss: 2.0892 - accuracy: 0.1853 - val_loss: 1.9968 - val_accuracy: 0.2898
# Epoch 2/30
# 572/572 [==============================] - 0s 363us/sample - loss: 1.8828 - accuracy: 0.3654 - val_loss: 1.8338 - val_accuracy: 0.3807
# Epoch 3/30
# 572/572 [==============================] - 0s 363us/sample - loss: 1.6702 - accuracy: 0.4161 - val_loss: 1.6178 - val_accuracy: 0.4432
# Epoch 4/30
# 572/572 [==============================] - 0s 358us/sample - loss: 1.4464 - accuracy: 0.5420 - val_loss: 1.4606 - val_accuracy: 0.5057
# Epoch 5/30
# 572/572 [==============================] - 0s 361us/sample - loss: 1.2911 - accuracy: 0.5857 - val_loss: 1.3333 - val_accuracy: 0.5625
# Epoch 6/30
# 572/572 [==============================] - 0s 360us/sample - loss: 1.1172 - accuracy: 0.6836 - val_loss: 1.2094 - val_accuracy: 0.6023
# Epoch 7/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.9707 - accuracy: 0.7552 - val_loss: 1.0798 - val_accuracy: 0.6420
# Epoch 8/30
# 572/572 [==============================] - 0s 357us/sample - loss: 0.7913 - accuracy: 0.8182 - val_loss: 0.8883 - val_accuracy: 0.7330
# Epoch 9/30
# 572/572 [==============================] - 0s 359us/sample - loss: 0.6156 - accuracy: 0.8741 - val_loss: 0.7262 - val_accuracy: 0.7841
# Epoch 10/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.4789 - accuracy: 0.8899 - val_loss: 0.6170 - val_accuracy: 0.8011
# Epoch 11/30
# 572/572 [==============================] - 0s 359us/sample - loss: 0.3777 - accuracy: 0.9231 - val_loss: 0.5409 - val_accuracy: 0.8068
# Epoch 12/30
# 572/572 [==============================] - 0s 361us/sample - loss: 0.3108 - accuracy: 0.9283 - val_loss: 0.4810 - val_accuracy: 0.8239
# Epoch 13/30
# 572/572 [==============================] - 0s 358us/sample - loss: 0.2662 - accuracy: 0.9406 - val_loss: 0.4311 - val_accuracy: 0.8295
# Epoch 14/30
# 572/572 [==============================] - 0s 366us/sample - loss: 0.1977 - accuracy: 0.9580 - val_loss: 0.3911 - val_accuracy: 0.8409
# Epoch 15/30
# 572/572 [==============================] - 0s 362us/sample - loss: 0.1818 - accuracy: 0.9563 - val_loss: 0.3582 - val_accuracy: 0.8352
# Epoch 16/30
# 572/572 [==============================] - 0s 360us/sample - loss: 0.1608 - accuracy: 0.9528 - val_loss: 0.3162 - val_accuracy: 0.8523
# Epoch 17/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.1156 - accuracy: 0.9738 - val_loss: 0.2933 - val_accuracy: 0.8750
# Epoch 18/30
# 572/572 [==============================] - 0s 361us/sample - loss: 0.0977 - accuracy: 0.9773 - val_loss: 0.2663 - val_accuracy: 0.8920
# Epoch 19/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.0781 - accuracy: 0.9878 - val_loss: 0.2474 - val_accuracy: 0.9148
# Epoch 20/30
# 572/572 [==============================] - 0s 370us/sample - loss: 0.0716 - accuracy: 0.9948 - val_loss: 0.2290 - val_accuracy: 0.9318
# Epoch 21/30
# 572/572 [==============================] - 0s 368us/sample - loss: 0.0601 - accuracy: 0.9895 - val_loss: 0.2145 - val_accuracy: 0.9205
# Epoch 22/30
# 572/572 [==============================] - 0s 362us/sample - loss: 0.0452 - accuracy: 0.9930 - val_loss: 0.2039 - val_accuracy: 0.9261
# Epoch 23/30
# 572/572 [==============================] - 0s 357us/sample - loss: 0.0441 - accuracy: 0.9878 - val_loss: 0.1944 - val_accuracy: 0.9261
# Epoch 24/30
# 572/572 [==============================] - 0s 356us/sample - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9318
# Epoch 25/30
# 572/572 [==============================] - 0s 360us/sample - loss: 0.0328 - accuracy: 0.9965 - val_loss: 0.1663 - val_accuracy: 0.9318
# Epoch 26/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.0304 - accuracy: 0.9948 - val_loss: 0.1653 - val_accuracy: 0.9318
# Epoch 27/30
# 572/572 [==============================] - 0s 362us/sample - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.9375
# Epoch 28/30
# 572/572 [==============================] - 0s 362us/sample - loss: 0.0216 - accuracy: 0.9965 - val_loss: 0.1565 - val_accuracy: 0.9318
# Epoch 29/30
# 572/572 [==============================] - 0s 359us/sample - loss: 0.0211 - accuracy: 0.9965 - val_loss: 0.1539 - val_accuracy: 0.9375
# Epoch 30/30
# 572/572 [==============================] - 0s 362us/sample - loss: 0.0176 - accuracy: 0.9983 - val_loss: 0.1438 - val_accuracy: 0.9432
# CPU times: user 21.8 s, sys: 4.81 s, total: 26.6 s
# Wall time: 12.3 s

# %%
# Display accuracy history during training
show_accuracy_history(hist)

# %%
# Display loss history during training
show_loss_history(hist)

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['lstm']['validation'] = clfs['lstm'].evaluate(Xp_val, y_val)
show_results(*results['lstm']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 94.32%
# CPU times: user 764 ms, sys: 333 ms, total: 1.1 s
# Wall time: 561 ms

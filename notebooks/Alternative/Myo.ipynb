# %% [markdown]
# # Introduction
#
# Experimentation on the [UC2018 DualMyo Hand Gesture Dataset](https://zenodo.org/record/1320922#.Xi9l5xfgoWo).

# %%
import os, sys, requests, pickle
import numpy as np, matplotlib.pyplot as plt
from sequentia.classifiers import HMM, HMMClassifier, DTWKNN
from sequentia.preprocessing import Preprocess
from tqdm.auto import tqdm

# Silence TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Import utility functions and classes
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils import *
from lstm import LSTMClassifier

# ggplot style
plt.style.use('ggplot')

# Set seed for reproducible randomness
seed = 0
np.random.seed(seed)
rng = np.random.RandomState(seed)

# %%
n_classes = 8
classes = [str(i) for i in range(n_classes)]
classes
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']

# %%
clfs, results = {}, {'hmm': {}, 'knn': {}, 'lstm': {}}

# %%
X, y = [], []
url = 'https://zenodo.org/record/1320922/files/dualmyo_dataset.pkl'

try:
    file = 'dualmyo_dataset.pkl'
    print('Downloading dataset from {} ...'.format(url))
    response = requests.get(url)
    with open(file, 'wb') as f:
        print('Writing {} ...'.format(file))
        f.write(response.content)
except:
    raise
else:
    print('Unpickling data into Numpy arrays ...')
    data = pickle.load(open(file, 'rb'))
    X = data[0]
    y = [str(label) for label in data[1]]
    print('Done!')
finally:
    os.remove(file)
# Out:
# Downloading dataset from https://zenodo.org/record/1320922/files/dualmyo_dataset.pkl ...
# Writing dualmyo_dataset.pkl ...
# Unpickling data into Numpy arrays ...
# Done!

# %% [markdown]
# ## Dataset splits
#
# Create a stratified 65-20-15 training, validation and test set split.

# %%
# Create a stratified training, validation and test set split (65-20-15)
X_train, X_val, X_test, y_train, y_val, y_test = data_split(X, y, random_state=rng, stratify=True)
# Out:
# Training set size: 572
# Validation set size: 176
# Test set size: 133

# %%
# DualMyo dataset class counts (training set)
show_class_counts(y_train, classes, title=None)

# %%
# Histogram of DualMyo dataset gesture durations (training set)
show_durations(X_train, bins=75, title=None)

# %% [markdown]
# ## Preprocessing

# %%
# Create a preprocessing pipeline
pre = Preprocess()
pre.filtrate(n=5, method='median')
pre.downsample(n=10, method='decimate')
pre.center()
pre.summary()
# Out:
#            Preprocessing summary:
# ===========================================
# 1. Filtering:
#    Median filter with window size (n=5)
# -------------------------------------------
# 2. Downsampling:
#    Decimation with downsample factor (n=10)
# -------------------------------------------
# 3. Centering
# ===========================================

# %%
# Pick an example signal for visualization
x = X_train[1]

plt.figure(figsize=(16, 3))
plt.title('Example signal before preprocessing')
plt.plot(x)
plt.show()

plt.figure(figsize=(16, 3))
plt.title('Example signal after preprocessing')
plt.plot(pre.transform(x))
plt.show()

# %%
# Transform training data and plot histogram of DualMyo dataset gesture durations (preprocessed) (training set)
Xp_train = pre.transform(X_train)
show_durations(Xp_train, bins=75, title=None)

# %%
# Apply the preprocessing pipeline to the other dataset splits
Xp_val, Xp_test = pre.transform(X_val), pre.transform(X_test)

# %% [markdown]
# ## DTWKNN classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
# Create and fit a DTWKNN classifier using the single nearest neighbor and a radius of 1
# NOTE: The radius parameter is a parameter that constrains the FastDTW algorithm.
clfs['knn'] = DTWKNN(k=1, radius=1)
clfs['knn'].fit(Xp_train, y_train)
# Out:
# CPU times: user 2 ms, sys: 1.42 ms, total: 3.42 ms
# Wall time: 2.6 ms

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['knn']['validation'] = clfs['knn'].evaluate(Xp_val, y_val, labels=classes, n_jobs=-1)
show_results(*results['knn']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 12.50%
# CPU times: user 596 ms, sys: 405 ms, total: 1 s
# Wall time: 1min 43s

# %% [markdown]
# ## Hidden Markov Model classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time

# Create HMMs to represent each class
#
# NumPy sometimes raises some errors as a result of instability during the Cholesky decomposition.
# According to issue #414 on Pomegranate's GitHub repository, this may be caused by:
# - Too many states in the HMMs
# - Too many dimensions in the input data, which leads to a large covariance matrix
# - Too few training examples
hmms = []
for c in tqdm(classes, desc='Training HMMs'):
    hmm = HMM(label=c, n_states=7, random_state=rng)
    hmm.set_random_initial()
    hmm.set_random_transitions()
    hmm.fit([Xp_train[i] for i, label in enumerate(y_train) if label == c])
    hmms.append(hmm)
    
# Fit a HMM classifier with the HMMs
clfs['hmm'] = HMMClassifier()
clfs['hmm'].fit(hmms)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Training HMMs', max=8.0, style=ProgressStyle(description_…
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 19-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 19-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 20-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 17-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 18-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 9-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 8-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 7-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 9-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ...
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 15-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 91                          check_finite=check_finite)
#      92     return c
#
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      39         raise LinAlgError("%d-th leading minor of the array is not positive "
# ---> 40                           "definite" % info)
#      41     if info < 0:
#
# LinAlgError: 14-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# ~/miniconda2/envs/adchhg/lib/python3.7/site-packages/pomegranate/distributions/MultivariateGaussianDistribution.pyx in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries()
#
# UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# Exception ignored in: 'pomegranate.hmm.HiddenMarkovModel._from_summaries'
# Traceback (most recent call last):
#   File "pomegranate/distributions/MultivariateGaussianDistribution.pyx", line 272, in pomegranate.distributions.MultivariateGaussianDistribution.MultivariateGaussianDistribution.from_summaries
# numpy.core._exceptions.UFuncTypeError: Cannot cast ufunc 'subtract' output from dtype('complex128') to dtype('float64') with casting rule 'same_kind'
# CPU times: user 1min 12s, sys: 1min 20s, total: 2min 33s
# Wall time: 27.2 s

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['hmm']['validation'] = clfs['hmm'].evaluate(Xp_val, y_val, labels=classes)
show_results(*results['hmm']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 99.43%
# CPU times: user 596 ms, sys: 141 ms, total: 737 ms
# Wall time: 551 ms

# %% [markdown]
# ## LSTM classifier

# %% [markdown]
# ### Fitting the model

# %%
# %%time
clfs['lstm'] = LSTMClassifier(epochs=30, batch_size=64, classes=classes)
hist = clfs['lstm'].fit(Xp_train, y_train, validation_data=(Xp_val, y_val), return_history=True)
# Out:
# Train on 572 samples, validate on 176 samples
# Epoch 1/30
# 572/572 [==============================] - 1s 3ms/sample - loss: 2.0599 - accuracy: 0.1941 - val_loss: 1.9574 - val_accuracy: 0.3409
# Epoch 2/30
# 572/572 [==============================] - 0s 366us/sample - loss: 1.8813 - accuracy: 0.3077 - val_loss: 1.8188 - val_accuracy: 0.4545
# Epoch 3/30
# 572/572 [==============================] - 0s 357us/sample - loss: 1.6946 - accuracy: 0.4808 - val_loss: 1.6390 - val_accuracy: 0.5511
# Epoch 4/30
# 572/572 [==============================] - 0s 361us/sample - loss: 1.4697 - accuracy: 0.5647 - val_loss: 1.4305 - val_accuracy: 0.6420
# Epoch 5/30
# 572/572 [==============================] - 0s 364us/sample - loss: 1.2448 - accuracy: 0.6311 - val_loss: 1.2672 - val_accuracy: 0.6250
# Epoch 6/30
# 572/572 [==============================] - 0s 359us/sample - loss: 1.0376 - accuracy: 0.7360 - val_loss: 1.0977 - val_accuracy: 0.7443
# Epoch 7/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.8661 - accuracy: 0.8042 - val_loss: 0.8960 - val_accuracy: 0.7727
# Epoch 8/30
# 572/572 [==============================] - 0s 365us/sample - loss: 0.6693 - accuracy: 0.8549 - val_loss: 0.7353 - val_accuracy: 0.8182
# Epoch 9/30
# 572/572 [==============================] - 0s 368us/sample - loss: 0.5264 - accuracy: 0.8934 - val_loss: 0.6227 - val_accuracy: 0.8352
# Epoch 10/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.4137 - accuracy: 0.9091 - val_loss: 0.5316 - val_accuracy: 0.8352
# Epoch 11/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.3301 - accuracy: 0.9248 - val_loss: 0.4596 - val_accuracy: 0.8409
# Epoch 12/30
# 572/572 [==============================] - 0s 355us/sample - loss: 0.2730 - accuracy: 0.9371 - val_loss: 0.4109 - val_accuracy: 0.8352
# Epoch 13/30
# 572/572 [==============================] - 0s 358us/sample - loss: 0.2102 - accuracy: 0.9476 - val_loss: 0.3842 - val_accuracy: 0.8466
# Epoch 14/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.1848 - accuracy: 0.9493 - val_loss: 0.3865 - val_accuracy: 0.8466
# Epoch 15/30
# 572/572 [==============================] - 0s 359us/sample - loss: 0.1556 - accuracy: 0.9650 - val_loss: 0.3328 - val_accuracy: 0.8466
# Epoch 16/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.1389 - accuracy: 0.9633 - val_loss: 0.3104 - val_accuracy: 0.8693
# Epoch 17/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.0960 - accuracy: 0.9860 - val_loss: 0.2881 - val_accuracy: 0.8864
# Epoch 18/30
# 572/572 [==============================] - 0s 366us/sample - loss: 0.0942 - accuracy: 0.9755 - val_loss: 0.2710 - val_accuracy: 0.8750
# Epoch 19/30
# 572/572 [==============================] - 0s 361us/sample - loss: 0.0808 - accuracy: 0.9825 - val_loss: 0.2605 - val_accuracy: 0.8864
# Epoch 20/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.0572 - accuracy: 0.9913 - val_loss: 0.2433 - val_accuracy: 0.8864
# Epoch 21/30
# 572/572 [==============================] - 0s 363us/sample - loss: 0.0589 - accuracy: 0.9913 - val_loss: 0.2200 - val_accuracy: 0.8920
# Epoch 22/30
# 572/572 [==============================] - 0s 357us/sample - loss: 0.0444 - accuracy: 0.9930 - val_loss: 0.2027 - val_accuracy: 0.9034
# Epoch 23/30
# 572/572 [==============================] - 0s 360us/sample - loss: 0.0401 - accuracy: 0.9948 - val_loss: 0.1876 - val_accuracy: 0.9091
# Epoch 24/30
# 572/572 [==============================] - 0s 366us/sample - loss: 0.0297 - accuracy: 0.9965 - val_loss: 0.1749 - val_accuracy: 0.9091
# Epoch 25/30
# 572/572 [==============================] - 0s 367us/sample - loss: 0.0285 - accuracy: 0.9965 - val_loss: 0.1727 - val_accuracy: 0.9034
# Epoch 26/30
# 572/572 [==============================] - 0s 369us/sample - loss: 0.0264 - accuracy: 0.9930 - val_loss: 0.1658 - val_accuracy: 0.9091
# Epoch 27/30
# 572/572 [==============================] - 0s 370us/sample - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.1706 - val_accuracy: 0.9034
# Epoch 28/30
# 572/572 [==============================] - 0s 364us/sample - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9148
# Epoch 29/30
# 572/572 [==============================] - 0s 375us/sample - loss: 0.0184 - accuracy: 0.9983 - val_loss: 0.1436 - val_accuracy: 0.9205
# Epoch 30/30
# 572/572 [==============================] - 0s 359us/sample - loss: 0.0199 - accuracy: 0.9983 - val_loss: 0.1316 - val_accuracy: 0.9261
# CPU times: user 21.8 s, sys: 4.56 s, total: 26.4 s
# Wall time: 8.11 s

# %%
# Display accuracy history during training
show_accuracy_history(hist)

# %%
# Display loss history during training
show_loss_history(hist)

# %% [markdown]
# ### Evaluating the model

# %%
# %%time
results['lstm']['validation'] = clfs['lstm'].evaluate(Xp_val, y_val)
show_results(*results['lstm']['validation'], dataset='validation', labels=classes)
# Out:
# Accuracy: 92.61%
# CPU times: user 676 ms, sys: 156 ms, total: 832 ms
# Wall time: 557 ms
